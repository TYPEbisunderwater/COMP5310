# %% [markdown]
# # Project Stage 1: Explore Data (Yuxin Zhao: )

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv('Sydney Suburbs Reviews clean.csv')
data=data.drop(columns=['Unnamed: 0'])
data.head(3)
# Out:
#            Name             Region Population (rounded)*  Postcode  \
# 0       Hornsby  Upper North Shore                23,000      2077
# 1        Oatley   Southern Suburbs                10,500      2223
# 2  Dulwich Hill         Inner West                14,500      2203
#
#   Median House Price (2020) Median House Price (2021) % Change  \
# 0              1,150,000.00              1,400,000.00   21.74%
# 1              1,550,000.00              1,800,000.00   16.13%
# 2              1,500,000.00              1,900,000.00   26.67%
#
#   Median House Rent (per week) Median Apartment Price (2020)  \
# 0                       600.00                    645,000.00
# 1                       670.00                    780,000.00
# 2                       725.00                    780,000.00
#
#    Median Apartment Rent (per week)  ... Overall Rating    TopCountry1  \
# 0                             460.0  ...            7.1  Chinese 17.1%
# 1                             470.0  ...            7.0  English 23.0%
# 2                             475.0  ...            6.9  English 19.4%
#
#         TopCountry2       TopCountry3    TopCountry4    TopCountry5  \
# 0     English 16.8%  Australian 14.0%    Indian 5.9%     Irish 5.6%
# 1  Australian 21.1%      Chinese 9.8%     Irish 8.9%  Scottish 5.7%
# 2  Australian 16.4%        Irish 9.5%  Scottish 6.2%     Greek 5.2%
#
#                Recommend1              Recommend2         Recommend3  \
# 0        Recommend.FAMILY        Recommend.FAMILY  Recommend.RETIREE
# 1        Recommend.FAMILY  Recommend.PROFESSIONAL  Recommend.RETIREE
# 2  Recommend.PROFESSIONAL        Recommend.FAMILY  Recommend.RETIREE
#
#                Recommend4
# 0  Recommend.PROFESSIONAL
# 1          Recommend.NONE
# 2          Recommend.NONE
#
# [3 rows x 36 columns]

# %%
data1=data['Median House Price (2020)'].str.replace(",","")
data=(data1.astype('float'))/10000
data.describe()
# Out:
# count     98.000000
# mean     161.484694
# std       57.815537
# min       80.000000
# 25%      120.000000
# 50%      150.000000
# 75%      188.750000
# max      360.000000
# Name: Median House Price (2020), dtype: float64

# %%
plt.hist(data,rwidth=0.8)
plt.xlabel('Price/(10k)')
plt.ylabel('Simple Number')
plt.title('Hist graph of Median House Price(2020)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('Sydney Suburbs Reviews clean.csv')
data=data.drop(columns=['Unnamed: 0'])
data2=data[['Median House Price (2021)','Overall Rating']]
data3= data2['Median House Price (2021)'].str.replace(",","")
plt.scatter(data3.astype('float'), data2['Overall Rating'])
plt.title('House price 2021 vs Rate')
plt.xlabel('Price/1000000')
plt.ylabel('Rate')
plt.show()

# %%
data=pd.read_csv('Sydney Suburbs Reviews clean.csv')
data=data.drop(columns=['Unnamed: 0'])
data3=data['Overall Rating']
fig = plt.figure(figsize =(10, 7))
plt.boxplot(data3)
plt.title('Distribution of Rate')
plt.show()
